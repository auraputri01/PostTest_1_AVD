# %% [markdown]
# <a href="https://colab.research.google.com/github/auraputri01/PostTest_1_AVD/blob/main/PostTest1_AVD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Judul**
#
# ```
# Analisis Penjualan Dirty Cafe: Evaluasi Performa dan Stgrategi Peningkatan Revenue.
# ```

# %%
Analisis Penjualan Dirty Cafe: Evaluasi Performa dan Stgrategi Peningkatan Revenue.

# %% [markdown]
# ## **Studi Kasus**
#
# ```
# Industri cafe mengalami pertumbuhan signifikan dalam beberapa tahun terakhir, dengan kompetisi yang semakin ketat. Dirty Cafe, sebagai salah satu pemain di industri ini, memerlukan pemahaman mendalam tentang data penjualan untuk membuat keputusan bisnis yang lebih informed dan data-driven.
#
# Dalam era digital, data penjualan bukan hanya catatan transaksi, tetapi juga sumber insights berharga tentang preferensi konsumen, efektivitas strategi marketing, dan efisiensi operasional. Analisis data yang tepat dapat membantu bisnis mengoptimalkan inventory management, meningkatkan customer satisfaction, memaksimalkan revenue dan profitabilitas, serta mengidentifikasi peluang pertumbuhan bisnis.
# ```

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
path ='/content/drive/MyDrive/Dataset/dirty_cafe_sales.csv'

# %%
df = pd.read_csv(path)

# %%
df.head(30)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0       ERROR
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211   UNKNOWN        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867       NaN        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# ...

# %% [markdown]
# ### **Business Understanding**

# %% [markdown]
# 1. Business Objective
#
# ```
# Tujuan dari proyek ini yaitu untuk mengubah data transaksi mentah Dirty Cafe menjadi insights strategis yang actionable untuk meningkatkan performa bisnis melalui data-driven decision making.
# ```

# %% [markdown]
# 2. Assess Situation
#
# ```
# Dirty Cafe adalah sebuah cafe yang beroperasi di industri food & beverage dengan model bisnis retail B2C. Cafe ini memiliki sistem Point of Sale (POS) yang mencatat setiap transaksi penjualan, menghasilkan data historis yang dapat dianalisis untuk pengambilan keputusan strategis.
# ```

# %% [markdown]
# 3. Analytic Goals Project Plan
#
# ```
# Tujuan dari analisis ini yaitu untuk mengidentifikasi pola transaksi, mengevaluasi performa produk, dan memahami perilaku konsumen guna menghasilkan insights strategis yang dapat meningkatkan efisiensi operasional, dan kepuasan pelanggan.
# ```
